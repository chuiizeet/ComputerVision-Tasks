# %% [markdown]
# # Numpy and Image Assessment

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
myArr = np.ones(shape=(5,5))
myArr[:,:] = 10.

# %%
myArr
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
#Seed
np.random.seed(101)
randomArr = np.random.randint(low=0,high=100,size=(5,5))

# %%
randomArr.max()
# Out:
# 95

# %%
randomArr.min()
# Out:
# 4

# %%
#Load image
myPic = Image.open('00-puppy.jpg')

# %%
picnp = np.array(myPic)

# %%
picnp.shape
# Out:
# (1300, 1950, 3)

# %% [markdown]
# ## Blue Dog

# %%
picnp[:,:,0] = 0
picnp[:,:,1] = 0
plt.imshow(picnp)
